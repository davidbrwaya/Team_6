# %%
# Dependencies and Setup
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as py
from scipy.stats import pearsonr
from scipy.stats import linregress
import seaborn as sns

# %%
# Fitbit Data Files
daily_activity_path = 'data/dailyActivity_merged1.csv'
sleep_day_path = 'data/sleepDay_merged.csv'
weight_log_info_path = 'data/weightLogInfo_merged.csv'
# Read the daily activity results 
daily_activity = pd.read_csv(daily_activity_path)
sleep_day = pd.read_csv(sleep_day_path)
weight_log_info = pd.read_csv(weight_log_info_path)
# Combine the data into a single DataFrame
combined_df = pd.merge(daily_activity, sleep_day, on = 'Id')
combined_df = pd.merge(combined_df, weight_log_info , on = 'Id' )
combined_df.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    4/12/2016       13162            8.5              8.5
# 1  1503960366    4/12/2016       13162            8.5              8.5
# 2  1503960366    4/12/2016       13162            8.5              8.5
# 3  1503960366    4/12/2016       13162            8.5              8.5
# 4  1503960366    4/12/2016       13162            8.5              8.5
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                1.88                      0.55
# 1                       0.0                1.88                      0.55
# 2                       0.0                1.88                      0.55
# 3                       0.0                1.88                      0.55
# 4                       0.0                1.88                      0.55
#
#    LightActiveDistance  SedentaryActiveDistance  ...  TotalSleepRecords  \
# 0                 6.06                      0.0  ...                  1
# 1                 6.06                      0.0  ...                  1
# 2                 6.06                      0.0  ...                  2
# 3                 6.06                      0.0  ...                  2
# 4                 6.06                      0.0  ...                  1
#
#    TotalMinutesAsleep  TotalTimeInBed                  Date   WeightKg  \
# 0                 327             346  5/2/2016 11:59:59 PM  52.599998
# 1                 327             346  5/3/2016 11:59:59 PM  52.599998
# 2                 384             407  5/2/2016 11:59:59 PM  52.599998
# 3                 384             407  5/3/2016 11:59:59 PM  52.599998
# 4                 412             442  5/2/2016 11:59:59 PM  52.599998
#
#   WeightPounds   Fat    BMI  IsManualReport          LogId
# 0   115.963147  22.0  22.65            True  1462233599000
# 1   115.963147   NaN  22.65            True  1462319999000
# 2   115.963147  22.0  22.65            True  1462233599000
# 3   115.963147   NaN  22.65            True  1462319999000
# 4   115.963147  22.0  22.65            True  1462233599000
#
# [5 rows x 26 columns]

# %%
sleep_day.head()
# Out:
#            Id               SleepDay  TotalSleepRecords  TotalMinutesAsleep  \
# 0  1503960366  4/12/2016 12:00:00 AM                  1                 327
# 1  1503960366  4/13/2016 12:00:00 AM                  2                 384
# 2  1503960366  4/15/2016 12:00:00 AM                  1                 412
# 3  1503960366  4/16/2016 12:00:00 AM                  2                 340
# 4  1503960366  4/17/2016 12:00:00 AM                  1                 700
#
#    TotalTimeInBed
# 0             346
# 1             407
# 2             442
# 3             367
# 4             712

# %%
sleep_day.Id.value_counts()
# Out:
# 8378563200    32
# 6962181067    31
# 5553957443    31
# 4702921684    28
# 2026352035    28
# 3977333714    28
# 4445114986    28
# 5577150313    26
# 4319703577    26
# 1503960366    25
# 7086361926    24
# 4388161847    24
# 6117666160    18
# 8792009665    15
# 2347167796    15
# 4020332650     8
# 1927972279     5
# 4558609924     5
# 1644430081     4
# 6775888955     3
# 8053475328     3
# 1844505072     3
# 7007744171     2
# 2320127002     1
# Name: Id, dtype: int64

# %%
sleep_day['SleepDay'].describe()
# Out:
# count                       413
# unique                       31
# top       4/15/2016 12:00:00 AM
# freq                         17
# Name: SleepDay, dtype: object

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33702 entries, 0 to 33701
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        33702 non-null  int64
#  1   ActivityDate              33702 non-null  object
#  2   TotalSteps                33702 non-null  int64
#  3   TotalDistance             33702 non-null  float64
#  4   TrackerDistance           33702 non-null  float64
#  5   LoggedActivitiesDistance  33702 non-null  float64
#  6   VeryActiveDistance        33702 non-null  float64
#  7   ModeratelyActiveDistance  33702 non-null  float64
#  8   LightActiveDistance       33702 non-null  float64
#  9   SedentaryActiveDistance   33702 non-null  float64
#  10  VeryActiveMinutes         33702 non-null  int64
#  11  FairlyActiveMinutes       33702 non-null  int64
#  12  LightlyActiveMinutes      33702 non-null  int64
#  13  SedentaryMinutes          33702 non-null  int64
#  14  Calories                  33702 non-null  int64
#  15  SleepDay                  33702 non-null  object
#  16  TotalSleepRecords         33702 non-null  int64
#  17  TotalMinutesAsleep        33702 non-null  int64
#  18  TotalTimeInBed            33702 non-null  int64
#  19  Date                      33702 non-null  object
#  20  WeightKg                  33702 non-null  float64
#  21  WeightPounds              33702 non-null  float64
#  22  Fat                       1581 non-null   float64
#  23  BMI                       33702 non-null  float64
#  24  IsManualReport            33702 non-null  bool
#  25  LogId                     33702 non-null  int64
# dtypes: bool(1), float64(11), int64(11), object(3)
# memory usage: 6.7+ MB

# %%
combined_df.describe()
# Out:
#                  Id    TotalSteps  TotalDistance  TrackerDistance  \
# count  3.370200e+04  33702.000000   33702.000000     33702.000000
# mean   6.474278e+09   9656.934930       6.490486         6.433641
# std    1.326641e+09   3917.366741       2.670941         2.620098
# min    1.503960e+09      0.000000       0.000000         0.000000
# 25%    6.962181e+09   5908.000000       3.910000         3.910000
# 50%    6.962181e+09  10320.000000       6.820000         6.820000
# 75%    6.962181e+09  12207.000000       8.350000         8.130000
# max    6.962181e+09  20031.000000      13.240000        13.240000
#
#        LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# count              33702.000000        33702.000000              33702.000000
# mean                   0.276905            1.612673                  0.912832
# std                    0.934911            1.516937                  0.784924
# min                    0.000000            0.000000                  0.000000
# 25%                    0.000000            0.000000                  0.190000
# 50%                    0.000000            1.200000                  0.680000
# 75%                    0.000000            3.020000                  1.680000
# max                    4.081692            7.650000                  2.390000
#
#        LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  ...  \
# count         33702.000000             33702.000000       33702.000000  ...
# mean              3.941401                 0.005795          23.727286  ...
# std               1.364677                 0.024006          23.960270  ...
# min               0.000000                 0.000000           0.000000  ...
# 25%               3.240000                 0.000000           0.000000  ...
# 50%               3.910000                 0.000000          18.000000  ...
# 75%               4.880000                 0.000000          38.000000  ...
# max               7.700000                 0.110000         210.000000  ...
#
#        SedentaryMinutes      Calories  TotalSleepRecords  TotalMinutesAsleep  \
# count      33702.000000  33702.000000       33702.000000        33702.000000
# mean         689.446858   2011.015667           1.091953          437.455492
# std          168.468180    382.641675           0.374875           85.671183
# min            0.000000      0.000000           1.000000           59.000000
# 25%          634.000000   1850.000000           1.000000          411.000000
# 50%          683.000000   2039.000000           1.000000          442.000000
# 75%          731.000000   2173.000000           1.000000          476.000000
# max         1440.000000   4552.000000           3.000000          750.000000
#
#        TotalTimeInBed      WeightKg  WeightPounds          Fat           BMI  \
# count    33702.000000  33702.000000  33702.000000  1581.000000  33702.000000
# mean       456.271468     62.849395    138.559198    23.529412     24.399954
# std         89.113600      7.258473     16.002193     1.500186      1.912757
# min         65.000000     52.599998    115.963147    22.000000     22.650000
# 25%        424.000000     61.200001    134.922906    22.000000     23.889999
# 50%        457.000000     61.500000    135.584291    25.000000     24.000000
# 75%        497.000000     61.900002    136.466144    25.000000     24.170000
# max        775.000000    133.500000    294.317120    25.000000     47.540001
#
#               LogId
# count  3.370200e+04
# mean   1.461797e+12
# std    7.753381e+08
# min    1.460506e+12
# 25%    1.461024e+12
# 50%    1.461888e+12
# 75%    1.462406e+12
# max    1.463098e+12
#
# [8 rows x 22 columns]

# %%
combined_df.corr()
# Out:
# C:\Users\dbirw\AppData\Local\Temp\ipykernel_12928\2236743958.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   combined_df.corr()
#                                 Id  TotalSteps  TotalDistance  \
# Id                        1.000000    0.007517       0.026314
# TotalSteps                0.007517    1.000000       0.991463
# TotalDistance             0.026314    0.991463       1.000000
# TrackerDistance           0.018845    0.997868       0.993738
# LoggedActivitiesDistance  0.108932    0.206249       0.308825
# VeryActiveDistance       -0.048824    0.767146       0.800117
# ModeratelyActiveDistance  0.118122    0.585942       0.602032
# LightActiveDistance       0.056307    0.755382       0.724432
# SedentaryActiveDistance   0.088781    0.175420       0.272046
# VeryActiveMinutes        -0.062842    0.676031       0.709279
# FairlyActiveMinutes       0.042744    0.581995       0.585978
# LightlyActiveMinutes      0.128511    0.650851       0.623361
# SedentaryMinutes         -0.378823   -0.187342      -0.187715
# Calories                 -0.005370    0.635681       0.660036
# TotalSleepRecords         0.009643   -0.006301      -0.006593
# TotalMinutesAsleep        0.283267    0.009172       0.016662
# TotalTimeInBed            0.256624    0.007518       0.015129
# WeightKg                 -0.159075   -0.225702      -0.193713
# WeightPounds             -0.159075   -0.225702      -0.193713
# Fat                       1.000000   -0.601677      -0.562688
# BMI                      -0.294973   -0.234461      -0.216205
# IsManualReport            0.191263    0.111139       0.076020
# LogId                    -0.054086    0.046656       0.035757
#
#                           TrackerDistance  LoggedActivitiesDistance  \
# Id                               0.018845                  0.108932
# TotalSteps                       0.997868                  0.206249
# TotalDistance                    0.993738                  0.308825
# TrackerDistance                  1.000000                  0.229707
# LoggedActivitiesDistance         0.229707                  1.000000
# VeryActiveDistance               0.782946                  0.406073
# ModeratelyActiveDistance         0.582464                  0.294395
# LightActiveDistance              0.743913                 -0.026811
# SedentaryActiveDistance          0.185909                  0.823015
# VeryActiveMinutes                0.698215                  0.261080
# FairlyActiveMinutes              0.584242                  0.158171
# LightlyActiveMinutes             0.641732                 -0.013307
# SedentaryMinutes                -0.192652                 -0.058085
# Calories                         0.663322                  0.115172
# TotalSleepRecords               -0.007000                  0.003809
# TotalMinutesAsleep               0.014315                  0.036456
# TotalTimeInBed                   0.013023                  0.032764
# WeightKg                        -0.193598                 -0.052888
# WeightPounds                    -0.193598                 -0.052888
# Fat                             -0.562688                       NaN
# BMI                             -0.216181                 -0.057598
# IsManualReport                   0.073830                  0.050033
# LogId                            0.036228                  0.003037
#
#                           VeryActiveDistance  ModeratelyActiveDistance  \
# Id                                 -0.048824                  0.118122
# TotalSteps                          0.767146                  0.585942
# TotalDistance                       0.800117                  0.602032
# TrackerDistance                     0.782946                  0.582464
# LoggedActivitiesDistance            0.406073                  0.294395
# VeryActiveDistance                  1.000000                  0.324932
# ModeratelyActiveDistance            0.324932                  1.000000
# LightActiveDistance                 0.274169                  0.247444
# SedentaryActiveDistance             0.304817                  0.303602
# VeryActiveMinutes                   0.914223                  0.318472
# FairlyActiveMinutes                 0.314848                  0.954656
# LightlyActiveMinutes                0.184839                  0.211174
# SedentaryMinutes                   -0.084515                 -0.184572
# Calories                            0.546399                  0.351993
# TotalSleepRecords                  -0.000719                  0.000182
# TotalMinutesAsleep                  0.004925                  0.027286
# TotalTimeInBed                      0.006968                  0.023238
# WeightKg                           -0.080769                 -0.117540
# WeightPounds                       -0.080769                 -0.117540
# Fat                                -0.814657                 -0.289774
# BMI                                -0.137554                 -0.129646
# IsManualReport                     -0.111438                  0.077202
# LogId                               0.007178                  0.016100
#
#                           LightActiveDistance  SedentaryActiveDistance  \
# Id                                   0.056307                 0.088781
# TotalSteps                           0.755382                 0.175420
# TotalDistance                        0.724432                 0.272046
# TrackerDistance                      0.743913                 0.185909
# LoggedActivitiesDistance            -0.026811                 0.823015
# VeryActiveDistance                   0.274169                 0.304817
# ModeratelyActiveDistance             0.247444                 0.303602
# LightActiveDistance                  1.000000                 0.003711
# SedentaryActiveDistance              0.003711                 1.000000
# VeryActiveMinutes                    0.195823                 0.208568
# FairlyActiveMinutes                  0.255258                 0.172805
# LightlyActiveMinutes                 0.926093                 0.016372
# SedentaryMinutes                    -0.211886                -0.021861
# Calories                             0.478154                 0.110485
# TotalSleepRecords                   -0.010515                 0.003105
# TotalMinutesAsleep                   0.005561                 0.029712
# TotalTimeInBed                       0.001976                 0.026703
# WeightKg                            -0.237348                -0.043104
# WeightPounds                        -0.237348                -0.043104
# Fat                                 -0.108988                      NaN
# BMI                                 -0.214057                -0.046943
# IsManualReport                       0.226752                 0.040778
# LogId                                0.054808                 0.002475
#
#                           VeryActiveMinutes  ...  Calories  TotalSleepRecords  \
# Id                                -0.062842  ... -0.005370           0.009643
# TotalSteps                         0.676031  ...  0.635681          -0.006301
# TotalDistance                      0.709279  ...  0.660036          -0.006593
# TrackerDistance                    0.698215  ...  0.663322          -0.007000
# LoggedActivitiesDistance           0.261080  ...  0.115172           0.003809
# VeryActiveDistance                 0.914223  ...  0.546399          -0.000719
# ModeratelyActiveDistance           0.318472  ...  0.351993           0.000182
# LightActiveDistance                0.195823  ...  0.478154          -0.010515
# SedentaryActiveDistance            0.208568  ...  0.110485           0.003105
# VeryActiveMinutes                  1.000000  ...  0.698308          -0.007056
# FairlyActiveMinutes                0.389313  ...  0.463739          -0.005378
# LightlyActiveMinutes               0.112419  ...  0.476133          -0.014337
# SedentaryMinutes                  -0.081882  ...  0.089998           0.003397
# Calories                           0.698308  ...  1.000000          -0.009895
# TotalSleepRecords                 -0.007056  ... -0.009895           1.000000
# TotalMinutesAsleep                -0.004934  ...  0.004127           0.405612
# TotalTimeInBed                     0.001487  ...  0.012549           0.448982
# WeightKg                           0.094527  ...  0.382135           0.033894
# WeightPounds                       0.094527  ...  0.382135           0.033894
# Fat                               -0.831970  ...  0.279665          -0.088252
# BMI                               -0.038540  ...  0.218278           0.049336
# IsManualReport                    -0.347911  ... -0.508517          -0.017843
# LogId                             -0.044122  ... -0.114545          -0.007454
#
#                           TotalMinutesAsleep  TotalTimeInBed  WeightKg  \
# Id                                  0.283267        0.256624 -0.159075
# TotalSteps                          0.009172        0.007518 -0.225702
# TotalDistance                       0.016662        0.015129 -0.193713
# TrackerDistance                     0.014315        0.013023 -0.193598
# LoggedActivitiesDistance            0.036456        0.032764 -0.052888
# VeryActiveDistance                  0.004925        0.006968 -0.080769
# ModeratelyActiveDistance            0.027286        0.023238 -0.117540
# LightActiveDistance                 0.005561        0.001976 -0.237348
# SedentaryActiveDistance             0.029712        0.026703 -0.043104
# VeryActiveMinutes                  -0.004934        0.001487  0.094527
# FairlyActiveMinutes                 0.016250        0.016618 -0.021795
# LightlyActiveMinutes               -0.030280       -0.035333 -0.228699
# SedentaryMinutes                   -0.254163       -0.242937  0.233380
# Calories                            0.004127        0.012549  0.382135
# TotalSleepRecords                   0.405612        0.448982  0.033894
# TotalMinutesAsleep                  1.000000        0.991120 -0.025807
# TotalTimeInBed                      0.991120        1.000000 -0.012849
# WeightKg                           -0.025807       -0.012849  1.000000
# WeightPounds                       -0.025807       -0.012849  1.000000
# Fat                                 0.482496        0.486638  1.000000
# BMI                                -0.086495       -0.074724  0.931827
# IsManualReport                      0.015660       -0.001065 -0.813286
# LogId                              -0.043625       -0.044798 -0.232090
#
#                           WeightPounds       Fat       BMI  IsManualReport  \
# Id                           -0.159075  1.000000 -0.294973        0.191263
# TotalSteps                   -0.225702 -0.601677 -0.234461        0.111139
# TotalDistance                -0.193713 -0.562688 -0.216205        0.076020
# TrackerDistance              -0.193598 -0.562688 -0.216181        0.073830
# LoggedActivitiesDistance     -0.052888       NaN -0.057598        0.050033
# VeryActiveDistance           -0.080769 -0.814657 -0.137554       -0.111438
# ModeratelyActiveDistance     -0.117540 -0.289774 -0.129646        0.077202
# LightActiveDistance          -0.237348 -0.108988 -0.214057        0.226752
# SedentaryActiveDistance      -0.043104       NaN -0.046943        0.040778
# VeryActiveMinutes             0.094527 -0.831970 -0.038540       -0.347911
# FairlyActiveMinutes          -0.021795 -0.287547 -0.077831       -0.076500
# LightlyActiveMinutes         -0.228699  0.047143 -0.203105        0.261290
# SedentaryMinutes              0.233380 -0.221536  0.313263       -0.158745
# Calories                      0.382135  0.279665  0.218278       -0.508517
# TotalSleepRecords             0.033894 -0.088252  0.049336       -0.017843
# TotalMinutesAsleep           -0.025807  0.482496 -0.086495        0.015660
# TotalTimeInBed               -0.012849  0.486638 -0.074724       -0.001065
# WeightKg                      1.000000  1.000000  0.931827       -0.813286
# WeightPounds                  1.000000  1.000000  0.931827       -0.813286
# Fat                           1.000000  1.000000  1.000000             NaN
# BMI                           0.931827  1.000000  1.000000       -0.604012
# IsManualReport               -0.813286       NaN -0.604012        1.000000
# LogId                        -0.232090 -1.000000 -0.185321        0.212210
#
#                              LogId
# Id                       -0.054086
# TotalSteps                0.046656
# TotalDistance             0.035757
# TrackerDistance           0.036228
# LoggedActivitiesDistance  0.003037
# VeryActiveDistance        0.007178
# ModeratelyActiveDistance  0.016100
# LightActiveDistance       0.054808
# SedentaryActiveDistance   0.002475
# VeryActiveMinutes        -0.044122
# FairlyActiveMinutes      -0.008928
# LightlyActiveMinutes      0.053272
# SedentaryMinutes         -0.002983
# Calories                 -0.114545
# TotalSleepRecords        -0.007454
# TotalMinutesAsleep       -0.043625
# TotalTimeInBed           -0.044798
# WeightKg                 -0.232090
# WeightPounds             -0.232090
# Fat                      -1.000000
# BMI                      -0.185321
# IsManualReport            0.212210
# LogId                     1.000000
#
# [23 rows x 23 columns]

# %%
# Build DataFrame with values related to Fitbit Fitness
user_id = combined_df['Id']
total_steps = combined_df['TotalSteps']
total_distance = combined_df['TotalDistance']
calories = combined_df['Calories']
total_minutes_asleep = combined_df['TotalMinutesAsleep']
weight_kg = combined_df['WeightKg']
weight_pounds = combined_df['WeightPounds']
total_time_in_bed = combined_df['TotalTimeInBed']
very_active_distance = combined_df['VeryActiveDistance']
very_active_minutes = combined_df['VeryActiveMinutes']
# Create a DataFrame
combined_df = pd.DataFrame({
    'Id' : user_id,
    'TotalSteps' : total_steps,
    'TotalDistance' : total_distance,
    'Calories' : calories,
    'TotalMinutesAsleep' : total_minutes_asleep,
    'WeightKg' : weight_kg,
    'WeightPounds' : weight_pounds,
    'TotalTimeInBed' : total_time_in_bed,
    'VeryActiveDistance' : very_active_distance,
    'VeryActiveMinutes' : very_active_minutes,
    
})    
# Display the first few rows of the DataFrame
combined_df.head()
# Out:
#            Id  TotalSteps  TotalDistance  Calories  TotalMinutesAsleep  \
# 0  1503960366       13162            8.5      1985                 327
# 1  1503960366       13162            8.5      1985                 327
# 2  1503960366       13162            8.5      1985                 384
# 3  1503960366       13162            8.5      1985                 384
# 4  1503960366       13162            8.5      1985                 412
#
#     WeightKg  WeightPounds  TotalTimeInBed  VeryActiveDistance  \
# 0  52.599998    115.963147             346                1.88
# 1  52.599998    115.963147             346                1.88
# 2  52.599998    115.963147             407                1.88
# 3  52.599998    115.963147             407                1.88
# 4  52.599998    115.963147             442                1.88
#
#    VeryActiveMinutes
# 0                 25
# 1                 25
# 2                 25
# 3                 25
# 4                 25

# %%
# Calculate the sum of Total Minutes Asleep and Weight (Pounds)
total_minutes_asleep_sum = combined_df['TotalMinutesAsleep'].sum()
weight_sum = combined_df['WeightPounds'].sum()

# Plotting a pie chart
labels = ['Total Minutes Asleep', 'Weight (Pounds)']
sizes = [total_minutes_asleep_sum, weight_sum]

plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, colors=['lightgreen', 'lightcoral'])
plt.title('Proportion of Total Minutes Asleep and Weight (Pounds)')
plt.show()

# %%
#Plot Very Active Distance Vs. Very Active Minutes
sns.set(style="whitegrid")

plt.figure(figsize=(10, 6))
sns.regplot(x=combined_df['VeryActiveDistance'], y=combined_df['VeryActiveMinutes'], color='blue', scatter_kws={'alpha':0.7})
plt.title('Very Active Distance vs. Very Active Minutes with Regression Line')
plt.xlabel('Very Active Distance (miles)')
plt.ylabel('Very Active Minutes')
plt.show()

# %%
# Create bins for Very Active Distance
bins = [0, 2, 5, 10, float('inf')]
labels = ['0-2 miles', '2-5 miles', '5-10 miles', '10+ miles']

# Apply bins to the DataFrame
combined_df['DistanceCategory'] = pd.cut(combined_df['VeryActiveDistance'], bins=bins, labels=labels, right=False)

# Calculate the average Very Active Minutes for each category
avg_minutes_by_category = combined_df.groupby('DistanceCategory')['VeryActiveMinutes'].mean()

# Bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x=avg_minutes_by_category.index, y=avg_minutes_by_category, color='blue')
plt.title('Average Very Active Minutes by Distance Category')
plt.xlabel('Very Active Distance Category (miles)')
plt.ylabel('Average Very Active Minutes')
plt.show()

# %%
#Plot Total Steps vs Calories
# Scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(combined_df['TotalDistance'], combined_df['Calories'], alpha=0.5, label='Data Points')

# Linear regression
slope, intercept, r_value, p_value, std_err = linregress(combined_df['TotalDistance'], combined_df['Calories'])
line = slope * combined_df['TotalDistance'] + intercept

# Plotting the linear regression line
plt.plot(combined_df['TotalDistance'], line, color='red', label='Linear Regression Line')

plt.title('TotalDistance vs Calories with Linear Regression')
plt.xlabel('TotalDistance')
plt.ylabel('Calories')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Sorting the DataFrame by 'TotalDistance' for a meaningful line plot
sorted_df = combined_df.sort_values(by='TotalDistance')

# Line plot for Total Steps and Calories
plt.figure(figsize=(12, 6))
plt.plot(sorted_df['TotalDistance'], sorted_df['Calories'], marker='o', linestyle='-', color='blue')
plt.title('TotalDistance vs Calories')
plt.xlabel('TotalDistance')
plt.ylabel('Calories')
plt.grid(True)
plt.show()
